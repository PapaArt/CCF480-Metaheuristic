# %%
import pandas as pd
import seaborn as sns

sns.set()

# %%
data = pd.read_csv("./data/f2_1.csv")
data
# Out:
#        Algoritmo       Mínimo       Máximo        Média  Desvio-padrão
# 0            ILS -5181.410403 -1635.279090 -3598.466146     823.051649
# 1  Hill Climbing  -726.898506   518.437252    44.213857     309.675760

# %%
sns.boxplot(data=data, x="Mínimo", color="#2b9348")
# Out:
# <AxesSubplot: xlabel='Mínimo'>

# %%
sns.boxplot(data=data, x="Máximo", color="#012a4a")
# Out:
# <AxesSubplot: xlabel='Máximo'>

# %%
sns.boxplot(data=data, x="Média", color='#ffc600')
# Out:
# <AxesSubplot: xlabel='Média'>

# %%
sns.boxplot(data=data, x="Desvio-padrão", color='#8c0000')
# Out:
# <AxesSubplot: xlabel='Desvio-padrão'>

# %%
data = pd.read_csv("./data/f2_2.csv")
data
# Out:
#        Algoritmo       Mínimo       Máximo        Média  Desvio-padrão
# 0            ILS -6430.695249 -4358.288408 -5278.360207     617.200073
# 1  Hill Climbing  -981.905080   431.781303  -334.308930     430.011009

# %%
sns.boxplot(data=data, x="Mínimo", color="#80b918")
# Out:
# <AxesSubplot: xlabel='Mínimo'>

# %%
sns.boxplot(data=data, x="Máximo", color="#003f88")
# Out:
# <AxesSubplot: xlabel='Máximo'>

# %%
sns.boxplot(data=data, x="Média", color="#eeba0b")
# Out:
# <AxesSubplot: xlabel='Média'>

# %%
sns.boxplot(data=data, x="Desvio-padrão", color='#6a040f')
# Out:
# <AxesSubplot: xlabel='Desvio-padrão'>
