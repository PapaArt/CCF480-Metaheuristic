# %%
import pandas as pd
import seaborn as sns

sns.set()

# %%
data = pd.read_csv("./data/f1_1.csv")
df_1 = pd.DataFrame(data)
df_1
# Out:
#        Algoritmo    Mínimo     Máximo      Média  Desvio-padrão
# 0            ILS  0.653442  12.171277   5.906419       3.237835
# 1  Hill Climbing  0.042661  51.999420  24.431616      14.670080

# %%
sns.boxplot(data=data, x="Mínimo", color='g')
# Out:
# <AxesSubplot: xlabel='Mínimo'>

# %%
sns.boxplot(data=data, x="Máximo", color='b')
# Out:
# <AxesSubplot: xlabel='Máximo'>

# %%
sns.boxplot(data=data, x="Média", color='y')
# Out:
# <AxesSubplot: xlabel='Média'>

# %%
sns.boxplot(data=data, x="Desvio-padrão", color='r')
# Out:
# <AxesSubplot: xlabel='Desvio-padrão'>

# %%
data = pd.read_csv("./data/f1_2.csv")
df_2 = pd.DataFrame(data)
df_2
# Out:
#        Algoritmo    Mínimo     Máximo      Média  Desvio-padrão
# 0            ILS  0.175303  19.140065   6.080278       5.299212
# 1  Hill Climbing  0.020258  34.590015  13.061027      11.111981

# %%
sns.boxplot(data=data, x="Mínimo", color='#006400')
# Out:
# <AxesSubplot: xlabel='Mínimo'>

# %%
sns.boxplot(data=data, x="Máximo", color='#22577a')
# Out:
# <AxesSubplot: xlabel='Máximo'>

# %%
sns.boxplot(data=data, x="Média", color='#ffff3f')
# Out:
# <AxesSubplot: xlabel='Média'>

# %%
sns.boxplot(data=data, x="Desvio-padrão", color='#bf0603')
# Out:
# <AxesSubplot: xlabel='Desvio-padrão'>
